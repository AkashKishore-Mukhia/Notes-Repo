# %% [markdown]
# ### Inheritance:
#
# We can use members of one class inside another class by using following ways:
# - By Composition(Has-A Relationship)
# - By Inheritance(Is-A Relationship)

# %% [markdown]
# #### 1. By Composition:
# - By using class Name or by using reference variable we can access members of one class inside another class, is know as Composition.

# %%
class School:
    schoolName = 'J C School'
    def getSchoolDetails(self):
        return School.schoolName

class student:
    def __init__(self, sname, sroolno):
        self.sname = sname
        self.sroolno = sroolno
    def details(self, s):
        # using the varaible of class school
        print(s.getSchoolDetails)
        print(self.sname)
        print(self.sroolno)

# %%
S = School()
s = student('ram', 12930)
s.details(S)
# Out:
# J C School
# ram
# 12930

# %% [markdown]
# #### 2. By Inheritance:
#
# What ever variable, methods and constructor available in the parent class, by default will be available to the child classes. Hence the main advantage of inheritance is code reusability and we can extend existing functionality by adding some more extra functionality.
#
# `syntax:`
# ```python
# <Child_Class_Name>(<Parent_Class_Name>):
# ```

# %%
class School:
    schoolName = 'J C School'
    def getSchoolDetails(self):
        return School.schoolName

class student(School):
    def __init__(self, sname, sroolno):
        self.sname = sname
        self.sroolno = sroolno
    def details(self):
        # using the varaible of class school
        print(self.getSchoolDetails())
        print(self.sname)
        print(self.sroolno)

# %%
s = student('ram', 43439)
s.details()
# Out:
# J C School
# ram
# 43439

# %% [markdown]
# `Note:` Whatever method and members present inside the parent class are automatically available to the child class. so with the child class reference variable we can access all the method of both classes.

# %%
class P:
    a = 10
    def __init__(self):
        self.b = 20

class C(P):
    c = 30
    def __init__(self):
        # if we comment this line b will not be available to this class
        super().__init__()
        self.d = 40

# %%
c = C()
print(c.a, c.b, c.c, c.d)
# Out:
# 10 20 30 40

# %% [markdown]
# #### Types of Inheritance:

# %% [markdown]
# ##### 1. Single Inheritance:
#
# The concept of inheriting the properties from one class to another is know as single inheritance.

# %%
class P:
    def m1(self):
        print('P class method')

class C(P):
    def m2(self):
        print('C class method')

# %%
c = C()
c.m2()
c.m1()
# Out:
# C class method
# P class method

# %% [markdown]
# ##### 2. Multi Level Inheritance:
#
# The concept of inheriting properties of multiple classes to a single class with the concept of one after another in know as multi level inheritance.

# %%
class P:
    def m1(self):
        print('P class method')

class C(P):
    def m2(self):
        print('C class method')

class CC(C):
    def m3(self):
        print('CC class method')

# %%
cc = CC()
cc.m1()
cc.m2()
cc.m3()
# Out:
# P class method
# C class method
# CC class method

# %% [markdown]
# ##### 3. Hierarchical Inheritance:
#
# The concept of interiting properties from one class into multiple classes which are in same level is know as hierarchical interitance.

# %%
class P:
    def m(self):
        print('P class method')

class C1(P):
    def m1(self):
        print('C1 class method')

class C2(P):
    def m2(self):
        print('C2 class method')

# %%
c1 = C1()
c2 = C2()
c1.m()
c1.m1()
c2.m()
c2.m2()
# Out:
# P class method
# C1 class method
# P class method
# C2 class method

# %% [markdown]
# ##### 4. Multiple Inheritance
#
# The concept of inheriting from multiple class into a single class at a time is know as Multiple Inheritance.

# %%
class Frontend:
    def UI(self):
        print('UI is ready')

class Backend:
    def API(self):
        print('API\'s are ready')

class Webpage(Frontend, Backend):
    def Application(self):
        self.UI()
        self.API()
        print('Application is ready')

# %%
wp = Webpage()
wp.Application()
# Out:
# UI is ready
# API's are ready
# Application is ready

# %% [markdown]
# ##### 5. Hybrid Interitance:
#
# The concept of inheriting atleast two different inheriting techniques together is know as hybrid Inheritance.

# %% [markdown]
# ##### 6. Cyclic Inheritance:
#
# The concept of inheriting properties from one class to another class in a cyclic way, is called cyclic Inheritance. Python don't support cyclic inheritance.
#
# `Ex:`
# ```python
# # example1
# class A(B):
#     pass
# class B(A):
#     pass
#
# #example2
# class A(A):
#     pass
# ```

# %% [markdown]
# #### Supre() method:
#
# Super is a built-in method which is usefull to call super class constructor, variables, and methods from the child class.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def display(self):
        print('person name', self.name)
        print('person age', self.age)

class Student(Person):
    def __init__(self, name, roll):
        self.name = name
        self.roll = roll
        super().__init__(name, 23)
    def display(self):
        super().display()
        print('student name', self.name)
        print('student roll', self.roll)

# %%
s = Student('ram', 34)
s.display()
# Out:
# person name ram
# person age 23
# student name ram
# student roll 34

# %% [markdown]
# **How to call method of a particular super class :**
#
# We can use the following approaches
# 1. `super(<super-class_of_class_name>, self).<class_members>()`
# 2. `<class_name>.<class_members>(self)`

# %% [markdown]
# #### Various important points about super() :
#
# ##### Case 1:
# From child we are not allowed to access parent class instance variables using the super(), Compolsory we have to use self only.
#
# But we can access parent class static variables using super()

# %%
class P: 
    a = 10
    def __init__(self):
        self.b = 20

class C(P):
    def m1(self):
        print(super().a) # valid
        print(self.b) # valid
        print(super().b) # invalid

# %%
c = C()
c.m1()
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 2
#       1 c = C()
# ----> 2 c.m1()
#
# Cell In[93], line 10, in C.m1(self)
#       8 print(super().a) # valid
#       9 print(self.b) # valid
# ---> 10 print(super().b)
#
# AttributeError: 'super' object has no attribute 'b'

# %% [markdown]
# ##### Case 2:
# From child class constructor, instance method, we can access parent class instance, class, static methods by using super()

# %%
class P: 
    a = 10
    def __init__(self):
        print('Parent constructor')
    def m1(self):
        print('Parent class m1')

    @classmethod
    def m2(cls):
        print('Parent class m2')
    @staticmethod
    def m3():
        print('parent class m3')
    
class C(P):
    def __init__(self):
        super().__init__()
        super().m1()
        super().m2()
        super().m3()
    def m1(self):
        super().__init__()
        super().m1()
        super().m2()
        super().m3()

# %%
c = C()
c.m1()
# Out:
# Parent constructor
# Parent class m1
# Parent class m2
# parent class m3
# Parent constructor
# Parent class m1
# Parent class m2
# parent class m3

# %% [markdown]
# ##### Case 3:
# From child class, class method we can not access parent class instance and constructors by using super() dirctly(but indirectly possible), but we can access parent static and class methods.

# %%
class P: 
    a = 10
    def __init__(self):
        print('Parent constructor')
    def m1(self):
        print('Parent class m1')

    @classmethod
    def m2(cls):
        print('Parent class m2')
    @staticmethod
    def m3():
        print('parent class m3')
    
class C(P):
    @classmethod
    def m1(cls):
        # super().__init__() # invalid
        # super().m1() # invalid
        super().m2() # valid
        super().m3() # valid

# %%
c = C()
c.m1()
# Out:
# Parent constructor
# Parent class m2
# parent class m3

# %% [markdown]
# **How to access parent class instance and constuctor method from child class, class method**

# %%
class P: 
    a = 10
    def __init__(self):
        print('Parent constructor')
    def m1(self):
        print('Parent class m1')

    @classmethod
    def m2(cls):
        print('Parent class m2')
    @staticmethod
    def m3():
        print('parent class m3')
    
class C(P):
    @classmethod
    def m1(cls):
        super(C, cls).__init__(cls)
        super(C, cls).m1(cls)

# %%
c = C()
c.m1()
# Out:
# Parent constructor
# Parent constructor
# Parent class m1

# %% [markdown]
# ##### Case 4:
# In child class static method we are not allowed to use super() generally (but in a special way we can use)

# %%
class P:
    a = 10

class C(P):
    @staticmethod
    def m1():
        super().a

# %%
c = C()
c.m1()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[112], line 2
#       1 c = C()
# ----> 2 c.m1()
#
# Cell In[111], line 7, in C.m1()
#       5 @staticmethod
#       6 def m1():
# ----> 7     super().a
#
# RuntimeError: super(): no arguments

# %% [markdown]
# **How to call parent class static method from child class static method using super() :**

# %% [markdown]
# Python uses Method resolution order to indentify which parent method to call.
# the MRO ordre decides which method will call. We can use super method to explicitly tell which method to run.
#
# ```py
# # super(<after which class mro to skipp>, <which class mro to use>)

# %%
class sp:
    @staticmethod
    def m1():
        print('super parent class m1 method')


class p(sp):
    def __init__(self):
        print('parent class')
    
    @staticmethod
    def m1():
        print('parent class m1 method')

class c(p):
    @staticmethod
    def m1():
        # says to use c's mro and skip after p class
        super(p, c).m1()
        print('current class m1 method')


print(c.mro())
c = c().m1()

# %%
class P:
    @staticmethod
    def m1():
        print('parent class m1 method')

class C(P):
    @staticmethod
    def m1():
        super(C, C).m1()
        print('Child class m1 method')

# %%
c = C()
c.m1()
# Out:
# parent class m1 method
# Child class m1 method
