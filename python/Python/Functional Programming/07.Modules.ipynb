# %% [markdown]
# ## Module:
#
# A python script consist group of function, variable, classes, etc... is called a module, Every python file is act as a module.
#
# We can use a module using the `import` keyword in our scripts.

# %%
# including the math module using import
import math
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# `Note:` we can use any alias name for modules and libraries using the `as` keyword.

# %%
import math as m
m.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ### Reloading a Module
# By default module will be loaded only once eventhough we are importing multiple times.

# %% [markdown]
# ### Module naming conflict:
#
# If two module has same member and we are executing both, then in python the function in the most recent module will be considered.

# %% [markdown]
# `Note:` we can use the `dir()` function to list down all the members of a module.

# %%
# directory of the math module
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# __doc__ is a special variable that list downs the doc-string of a module 
m.__doc__
# Out:
# 'This module provides access to the mathematical functions\ndefined by the C standard.'

# %% [markdown]
# ### Special Varibale \_\_name\_\_:
#
# In python module(script) one of the special variable is `__name__`.
#
# The value of this variable changes based on the below scenario:
# - Direct execution of the module(script) -> `__name__` = `'__main__'`
# - Indirect execution(ex:import module) of the module -> `__name__` = `<module name>`

# %% [markdown]
# `Note:` Whenever `import` statement is encountered it executed the module(script) itself.

# %%
# direct execution of this module
__name__
# Out:
# '__main__'

# %%
# indirecto execution of chai module

from chai import chaipati
print(chaipati.__name__)
print(chaipati.whoareyou())
# Out:
# chai.chaipati
# chai.chaipati
# None
